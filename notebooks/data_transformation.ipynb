# %%
import pandas as pd

# %%
# Read data 
df = pd.read_csv('../data/cleaned_employee_data.csv')
df.head()
# Out:
#    Unnamed: 0  Employee ID        Name Department        Salary Joining Date  \
# 0           0            1  Employee 1         IT  56533.333333   2020-01-15
# 1           1            2  Employee 2         HR  55000.000000   2019-02-20
# 2           2            3  Employee 3    Finance  72000.000000   2018-03-10
# 3           3            4  Employee 4  Marketing  56533.333333   2021-04-25
# 4           4            5  Employee 5      Sales  48000.000000   2017-05-30
#
#    Years of Experience
# 0                    2
# 1                    3
# 2                    4
# 3                    1
# 4                    5

# %% [markdown]
# ## Create a new column, `Annual Bonus`, which is 10% of the Salary.

# %%
df['Annual Bonus'] = df['Salary'] * 0.10
df
# Out:
#     Unnamed: 0  Employee ID         Name Department        Salary  \
# 0            0            1   Employee 1         IT  56533.333333
# 1            1            2   Employee 2         HR  55000.000000
# 2            2            3   Employee 3    Finance  72000.000000
# 3            3            4   Employee 4  Marketing  56533.333333
# 4            4            5   Employee 5      Sales  48000.000000
# 5            5            6   Employee 6         IT  52000.000000
# 6            6            7   Employee 7         HR  60000.000000
# 7            7            8   Employee 8    Finance  67000.000000
# 8            8            9   Employee 9  Marketing  49000.000000
# 9            9           10  Employee 10      Sales  53000.000000
# 10          10           11  Employee 11         IT  56533.333333
# 11          11           12  Employee 12         HR  68000.000000
# 12          12           13  Employee 13    Finance  50000.000000
# ...

# %% [markdown]
# ## Filter the dataset to include only employees from the `IT` and `HR` departments.

# %%
it_hr_employees = df[df['Department'].isin(['IT', 'HR'])]
print(it_hr_employees)
# Out:
#     Unnamed: 0  Employee ID         Name Department        Salary  \
# 0            0            1   Employee 1         IT  56533.333333
# 1            1            2   Employee 2         HR  55000.000000
# 5            5            6   Employee 6         IT  52000.000000
# 6            6            7   Employee 7         HR  60000.000000
# 10          10           11  Employee 11         IT  56533.333333
# 11          11           12  Employee 12         HR  68000.000000
# 15          15           16  Employee 16         IT  61000.000000
# 16          16           17  Employee 17         HR  65000.000000
#
#    Joining Date  Years of Experience  Annual Bonus
# 0    2020-01-15                    2   5653.333333
# 1    2019-02-20                    3   5500.000000
# 5    2016-06-05                    6   5200.000000
# 6    2020-07-18                    2   6000.000000
# 10   2020-11-02                    2   5653.333333
# 11   2019-12-08                    3   6800.000000
# ...

# %% [markdown]
# ## Group the data by `Department` and calculate the average `Salary` and `Annual Bonus` for each department.
